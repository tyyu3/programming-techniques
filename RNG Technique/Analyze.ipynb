# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("timings.txt",header=None)
df = df.iloc[:, 1:]
df
# Out:
#       1        2        3        4        5         6         7         8   \
# 0   1000   112000   223000   334000   445000    556000    667000    778000
# 1   7200   679200  1347200  2015500  2692000   3380200   4100900   5288900
# 2   3700   256100   510500   796700  1035600   1539700   1522100   2623400
# 3  30600  2408300  4821800  7663800  9773600  13473300  17030500  17140500
#
#          9         10
# 0    889000   1000000
# 1   6955400   6349300
# 2   2831100   2551000
# 3  20155200  24863800

# %%
vals = df.values.tolist()
x = vals[0]
y1 = [x/10**9 for x in vals[1]]
y2 = [x/10**9 for x in vals[2]]
y3 = [x/10**9 for x in vals[3]]

# %%
plt.figure(figsize=(8,8))
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.xlabel('N', fontsize=18)
plt.ylabel('Time, seconds', fontsize=16)
plt.legend(['Effortless','Advanced','Mersenne-Twister'])
plt.savefig("Sorts.png")
