# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("timings.txt",header=None)
df = df.iloc[:, 1:]
df
# Out:
#        1           2           3            4            5            6   \
# 0     100       11200       22300        33400        44500        55600
# 1    2520      231220      436820       672100       971960      1136400
# 2    1160        3200        3000         2960         3900         5980
# 3   26440       31900       32160        30440        61080        48320
# 4     340        3140        2660         3220         4560         3700
# 5  121820  1342975040  5115899240  11445923380  20386388040  31776218440
#
#             7            8            9             10
# 0        66700        77800        88900         99999
# 1      1349340      1622240      1800260       2033340
# 2         4800         3080         3180         11220
# 3        71380        30760        31020        103040
# 4         4420         4600         4680          5640
# 5  45787285940  62882995500  82727693320  103682427780

# %%
vals = df.values.tolist()
x = vals[0]
y1 = [x/10**9 for x in vals[1]]
y2 = [x/10**9 for x in vals[2]]
y3 = [x/10**9 for x in vals[3]]
y4 = [x/10**9 for x in vals[4]]
y5 = [x/10**9 for x in vals[5]]

# %%
plt.figure(figsize=(8,8))
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.plot(x, y5)
plt.xlabel('N', fontsize=18)
plt.ylabel('Time, seconds', fontsize=16)
plt.legend(['Linear Search','Multimap','Multimap w. vector','Presorted Binary Search','Sort & Binary Search'])
plt.savefig("Search_w_sort.png")

# %%
plt.figure(figsize=(8,8))
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.xlabel('N', fontsize=18)
plt.ylabel('Time, seconds', fontsize=16)
plt.legend(['Linear Search','Multimap','Multimap w. vector','Presorted Binary Search'])
plt.savefig("Search_wo_sort.png")

# %%
plt.figure(figsize=(8,8))
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.xlabel('N', fontsize=18)
plt.ylabel('Time, seconds', fontsize=16)
plt.legend(['Multimap','Multimap w. vector','Presorted Binary Search'])
plt.savefig("Search_wo_sort_wo_lin.png")
