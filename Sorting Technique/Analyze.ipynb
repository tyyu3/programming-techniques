# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("timings.txt",header=None)
df = df.iloc[:, 1:]
df
# Out:
#       1          2           3           4            5            6   \
# 0    100      11200       22300       33400        44500        55600
# 1  41700  548950600  2130108000  4718191500   8340642200  13165457400
# 2  15700  128730900   568965800  1137969200   2058389400   2995741000
# 3  48100  760594800  2957271400  6730461300  11108269600  17531227500
#
#             7            8            9            10
# 0        66700        77800        88900       100000
# 1  18773285000  25904602300  33212812100  42714062800
# 2   4641061300   6384177800   8291017500  10545028600
# 3  25143370000  34246552100  45326297800  57204808400

# %%
vals = df.values.tolist()
x = vals[0]
y1 = [x/10**9 for x in vals[1]]
y2 = [x/10**9 for x in vals[2]]
y3 = [x/10**9 for x in vals[3]]

# %%
plt.figure(figsize=(8,8))
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.xlabel('N', fontsize=18)
plt.ylabel('Time, seconds', fontsize=16)
plt.legend(['Selection','Insertion','Shaker'])
plt.savefig("Sorts.png")
